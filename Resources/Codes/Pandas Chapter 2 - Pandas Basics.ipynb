# %% [markdown]
# ## 7.1.  Pandas Series

# %% [markdown]
# ### 7.1.1. Creating Pandas Series

# %%
# empty series

import pandas as pd 

my_series = pd.Series()
print(my_series)
# Out:
# Series([], dtype: float64)
# <ipython-input-1-aa2179222d9e>:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   my_series = pd.Series()

# %%
# series using numpy array

import pandas as pd
import numpy as np

my_array = np.array([10, 20, 30, 40, 50])

my_series = pd.Series(my_array)
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
# series with custom indexes

import pandas as pd
import numpy as np

my_array = np.array([10, 20, 30, 40, 50])

my_series = pd.Series(my_array, index = ["num1", "num2", "num3", "num4", "num5"])
print(my_series)
# Out:
# num1    10
# num2    20
# num3    30
# num4    40
# num5    50
# dtype: int32

# %%
# series using list

import pandas as pd
import numpy as np


my_series = pd.Series([10, 20, 30, 40, 50], index = ["num1", "num2", "num3", "num4", "num5"])
print(my_series)
# Out:
# num1    10
# num2    20
# num3    30
# num4    40
# num5    50
# dtype: int64

# %%
# series using scaler

import pandas as pd
import numpy as np


my_series = pd.Series(25, index = ["num1", "num2", "num3", "num4", "num5"])
print(my_series)
# Out:
# num1    25
# num2    25
# num3    25
# num4    25
# num5    25
# dtype: int64

# %%
# series using dictionary

my_dict = {'num1' : 6,
        'num2' : 7,
        'num3' : 8}

my_series = pd.Series(my_dict)
print(my_series)
# Out:
# num1    6
# num2    7
# num3    8
# dtype: int64

# %% [markdown]
# ### 7.1.2. Useful Operations on Pandas Series

# %%
## Accessing Items

import pandas as pd
my_series = pd.Series([10, 20, 30, 40, 50], index = ["num1", "num2", "num3", "num4", "num5"])
print(my_series[0])
print(my_series['num3'])
# Out:
# 10
# 30

# %%
## Finding Maximum and Minimum Values

import pandas as pd
import numpy as np

my_series = pd.Series([5, 8, 2, 11, 9])

print(np.min(my_series))
print(np.max(my_series))
# Out:
# 2
# 11

# %%
## Finding Mean

import pandas as pd
import numpy as np

my_series = pd.Series([5, 8, 2, 11, 9])

print(my_series.mean())
# Out:
# 7.0

# %%
## Finding Median

import pandas as pd
import numpy as np

my_series = pd.Series([5, 8, 2, 11, 9])

print(my_series.median())
# Out:
# 8.0

# %%
## Finding Data Type

import pandas as pd
import numpy as np

my_series = pd.Series([5, 8, 2, 11, 9])

print(my_series.dtype)
# Out:
# int64

# %%
## Converting to List

import pandas as pd
import numpy as np

my_series = pd.Series([5, 8, 2, 11, 9])

print(my_series.tolist())
# Out:
# [5, 8, 2, 11, 9]

# %% [markdown]
# ## 7.2.  Pandas Dataframes

# %% [markdown]
# ### 7.2.1. Creating Pandas Dataframe

# %%
# empty pandas dataframe

import pandas as pd

my_df = pd.DataFrame()
print(my_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# dataframe using list of lists

import pandas as pd
  
scores = [['Mathematics', 85], ['English', 91], ['History', 95]]
  
my_df = pd.DataFrame(scores, columns = ['Subject', 'Score'])
my_df
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      English     91
# 2      History     95

# %%
# dataframe using dictionaries

import pandas as pd

scores = {'Subject':["Mathematics", "History", "English", "Science", "Arts"],
           'Score':[98, 75, 68, 82, 99]
         }

my_df = pd.DataFrame(scores)
my_df
# Out:
#        Subject  Score
# 0  Mathematics     98
# 1      History     75
# 2      English     68
# 3      Science     82
# 4         Arts     99

# %%
# dataframe using list of dictionaries

import pandas as pd

scores = [
          {'Subject':'Mathematics', 'Score':85},
          {'Subject':'History', 'Score':98},
          {'Subject':'English', 'Score':76},
          {'Subject':'Science', 'Score':72},
          {'Subject':'Arts', 'Score':95},
         ]

my_df = pd.DataFrame(scores)
my_df
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      History     98
# 2      English     76
# 3      Science     72
# 4         Arts     95

# %%
# dataframe using list of dictionaries
# with null items

import pandas as pd

scores = [
          {'Subject':'Mathematics', 'Score':85},
          {'Subject':'History', 'Score':98},
          {'Subject':'English', 'Score':76},
          {'Score':72},
          {'Subject':'Arts', 'Score':95},
         ]

my_df = pd.DataFrame(scores)
my_df
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      History     98
# 2      English     76
# 3          NaN     72
# 4         Arts     95

# %% [markdown]
# ### 7.2.2. Basic Operations on Pandas Dataframe

# %%
# viewing header

import pandas as pd

scores = [
          {'Subject':'Mathematics', 'Score':85},
          {'Subject':'History', 'Score':98},
          {'Subject':'English', 'Score':76},
          {'Subject':'Science', 'Score':72},
          {'Subject':'Arts', 'Score':95},
         ]

my_df = pd.DataFrame(scores)

my_df.head(2)
# Out:
#        Subject  Score
# 0  Mathematics     85
# 1      History     98

# %%
# viewing tail

my_df = pd.DataFrame(scores)

my_df.tail(2)
# Out:
#    Subject  Score
# 3  Science     72
# 4     Arts     95

# %%
# getting dataframe info

my_df = pd.DataFrame(scores)

my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  5 non-null      object
#  1   Score    5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
# getting info about numeric columns

my_df = pd.DataFrame(scores)

my_df.describe()
# Out:
#            Score
# count   5.000000
# mean   85.200000
# std    11.388591
# min    72.000000
# 25%    76.000000
# 50%    85.000000
# 75%    95.000000
# max    98.000000

# %% [markdown]
# ## 7.3.  Importing Data in Pandas

# %% [markdown]
# ### 7.3.1. Importing CSV Files

# %%
import pandas as pd
titanic_data = pd.read_csv(r"D:\Datasets\iris_data.csv")
titanic_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
headers = ["Preg", "Glucose", "BP", "skinThick", "Insulin", "BMI", "DPF", "Age", "Class"]

patient_data = pd.read_csv(r"D:\Datasets\pima-indians-diabetes.csv", names = headers)

patient_data.head()
# Out:
#    Preg  Glucose  BP  skinThick  Insulin   BMI    DPF  Age  Class
# 0     6      148  72         35        0  33.6  0.627   50      1
# 1     1       85  66         29        0  26.6  0.351   31      0
# 2     8      183  64          0        0  23.3  0.672   32      1
# 3     1       89  66         23       94  28.1  0.167   21      0
# 4     0      137  40         35      168  43.1  2.288   33      1

# %% [markdown]
# ### 7.3.2. Importing TSV Files

# %%
import pandas as pd 
patients_csv = pd.read_csv(r"D:\Datasets\iris_data.tsv", sep='\t')
patients_csv.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth TrainingClass
# 0          5.1         3.5          1.4         0.2   Iris-setosa
# 1          4.9         3.0          1.4         0.2   Iris-setosa
# 2          4.7         3.2          1.3         0.2   Iris-setosa
# 3          4.6         3.1          1.5         0.2   Iris-setosa
# 4          5.0         3.6          1.4         0.2   Iris-setosa

# %% [markdown]
# ### 7.3.3. Importing Data from Databases

# %% [markdown]
# **Note:** To run the scripts in this section, you first have to create records table in the database named Titatic in the corresponding databases. The process of creating a table in SQL Server, PostgreSQL, and SQLite databases is beyond the scope of this book. Reference links are given in the book for that.

# %% [markdown]
# **Importing Data from SQL Server**

# %%
# pip install pyodbc

# %%
import pandas as pd
import pyodbc
 
sql_conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server}; SERVER=HOARE\SQLEXPRESS; DATABASE=Titanic;   Trusted_Connection=yes')

# %%
query = "SELECT * FROM records;"
titanic_data = pd.read_sql(query, sql_conn)
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1     False       3
# 1            2      True       1
# 2            3      True       3
# 3            4      True       1
# 4            5     False       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket       Fare Cabin Embarked
# 0      0         A/5 21171   7.250000  None        S
# 1      0          PC 17599  71.283302   C85        C
# 2      0  STON/O2. 3101282   7.925000  None        S
# 3      0            113803  53.099998  C123        S
# 4      0            373450   8.050000  None        S

# %% [markdown]
# **Importing Data from PostgreSQL**

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:abc123@localhost:5432/Titanic')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-a38d3b6d347f> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 engine = create_engine('postgresql://postgres:abc123@localhost:5432/Titanic')
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     498     strategy = kwargs.pop("strategy", default_strategy)
#     499     strategy = strategies.strategies[strategy]
# --> 500     return strategy.create(*args, **kwargs)
#     501
#     502
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in dbapi(cls)
#     776     @classmethod
#     777     def dbapi(cls):
# --> 778         import psycopg2
#     779
#     780         return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
import pandas as pd
titanic_data =pd.read_sql_query('select * from "records"',con=engine)
titanic_data.head()

# %% [markdown]
# **Importing Data from SQLite**

# %%
import sqlite3
import pandas as pd
# Create your connection.
cnx = sqlite3.connect('E:/Titanic.db')

# %%
titanic_data = pd.read_sql_query("SELECT * FROM records", cnx)
titanic_data.head()

# %% [markdown]
# ## 7.4.  Handling Missing Values in Pandas

# %% [markdown]
# ### 7.4.1. Handling Missing Numerical Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

plt.rcParams["figure.figsize"] = [8,6]
sns.set_style("darkgrid")

titanic_data = sns.load_dataset('titanic')

titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_data = titanic_data[["survived", "pclass", "age", "fare"]]
titanic_data.head()
# Out:
#    survived  pclass   age     fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
titanic_data.isnull().mean()
# Out:
# survived    0.000000
# pclass      0.000000
# age         0.198653
# fare        0.000000
# dtype: float64

# %%
median = titanic_data.age.median()
print(median)

mean = titanic_data.age.mean()
print(mean)
# Out:
# 28.0
# 29.69911764705882

# %%
import numpy as np

titanic_data['Median_Age'] = titanic_data.age.fillna(median)

titanic_data['Mean_Age'] = titanic_data.age.fillna(mean)

titanic_data['Mean_Age'] = np.round(titanic_data['Mean_Age'], 1)

titanic_data.head(20)
# Out:
#     survived  pclass   age     fare  Median_Age  Mean_Age
# 0          0       3  22.0   7.2500        22.0      22.0
# 1          1       1  38.0  71.2833        38.0      38.0
# 2          1       3  26.0   7.9250        26.0      26.0
# 3          1       1  35.0  53.1000        35.0      35.0
# 4          0       3  35.0   8.0500        35.0      35.0
# 5          0       3   NaN   8.4583        28.0      29.7
# 6          0       1  54.0  51.8625        54.0      54.0
# 7          0       3   2.0  21.0750         2.0       2.0
# 8          1       3  27.0  11.1333        27.0      27.0
# 9          1       2  14.0  30.0708        14.0      14.0
# 10         1       3   4.0  16.7000         4.0       4.0
# 11         1       1  58.0  26.5500        58.0      58.0
# 12         0       3  20.0   8.0500        20.0      20.0
# 13         0       3  39.0  31.2750        39.0      39.0
# 14         0       3  14.0   7.8542        14.0      14.0
# 15         1       2  55.0  16.0000        55.0      55.0
# 16         0       3   2.0  29.1250         2.0       2.0
# 17         1       2   NaN  13.0000        28.0      29.7
# 18         0       3  31.0  18.0000        31.0      31.0
# 19         1       3   NaN   7.2250        28.0      29.7

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

titanic_data['age'] .plot(kind='kde', ax=ax)

titanic_data['Median_Age'] .plot(kind='kde', ax=ax, color='red')

titanic_data['Mean_Age'] .plot(kind='kde', ax=ax, color='green')

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %% [markdown]
# ### 7.4.2. Handling Missing Categorial Values

# %% [markdown]
# **Frequent Category Imputation**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = [8,6]
sns.set_style("darkgrid")

titanic_data = sns.load_dataset('titanic')

titanic_data = titanic_data[["embark_town", "age", "fare"]]
titanic_data.head()
titanic_data.isnull().mean()

# %%
titanic_data.embark_town.value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('Embark Town')
plt.ylabel('Number of Passengers')

# %%
titanic_data.embark_town.mode()

# %%
titanic_data.embark_town.fillna('Southampton', inplace=True)

# %%
titanic_data.age.mode()

# %%
import numpy as np


titanic_data['age_mode'] = titanic_data.age.fillna(24)


titanic_data.head(20)

# %%
plt.rcParams["figure.figsize"] = [8,6]

fig = plt.figure()
ax = fig.add_subplot(111)

titanic_data['age'] .plot(kind='kde', ax=ax)

titanic_data['age_mode'] .plot(kind='kde', ax=ax, color='red')


lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %% [markdown]
# **Missing Category Imputation**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = [8,6]
sns.set_style("darkgrid")

titanic_data = sns.load_dataset('titanic')

titanic_data = titanic_data[["embark_town", "age", "fare"]]
titanic_data.head()
titanic_data.isnull().mean()

# %%
titanic_data.embark_town.fillna('Missing', inplace=True)

# %%
titanic_data.embark_town.value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('Embark Town')
plt.ylabel('Number of Passengers')

# %% [markdown]
# ## Exercise 7.1
#
#
# ### Question 1
#
# What is the major disadvantage of mean and median imputation?
#
# A. Distorts the data distribution
#
# B. Distorts the data variance
#
# C. Distorts the data covariance
#
# D. All of the Above
#
# Answer: D
#
#
# ### Question 2
#
# How to  display the last three rows of a pandas dataframe named "my_df":
#
# A. my_df.end(3)
#
# B. my_df.bottom(3)
#
# C. my_df.top(-3)
#
# D. my_df.tail(3)
#
# Answer: D
#
#
# ### Question 3
#
# You can create a Pandas series using a:
#
# A. NumPy Array
#
# B. List
#
# C. Dictionary
#
# D. All of the Above
#
# Answer: C

# %% [markdown]
# ## Exercise 7.2
#
# Replace the missing values in the "deck" column of the Titanic dataset by the most
# frequently occuring categories in that column. Plot a bar plot for the updated "deck" column.
# The titanic dataset can be downloaded using this seaborn command:
#
# ```
# import seaborn as sns
# sns.load_dataset('titanic')
# ```

# %% [markdown]
# **Solution:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = [8,6]
sns.set_style("darkgrid")

titanic_data = sns.load_dataset('titanic')

titanic_data  = titanic_data[["deck"]]
titanic_data.head()
titanic_data.isnull().mean()

titanic_data.deck.value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('deck')
plt.ylabel('Number of Passengers')

titanic_data.deck.mode()

titanic_data.deck.fillna('C', inplace=True)

titanic_data.deck.value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('deck')
plt.ylabel('Number of Passengers')
